# %%
pip install ethnicolr
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.5/39.5 MB 15.1 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import io

# Define a sample dataset with first name and last name
path="/content/profiles_extracted.csv"
df=pd.read_csv(path)
df.head()
# Out:
#    Unnamed: 0 firstName                 lastName  \
# 0           1      Sema                   Tuncer
# 1          25     Kevin  Mornot CISM, CASP, GCIH
# 2          42   Abraham                Mintesnot
# 3          59    Claire                    Selby
# 4          60    Daylon                  Frazier
#
#                                         schoolDegree  \
# 0  Master of Business Administration - MS, Busine...
# 1                                                NaN
# 2                Major: Psychology | Minor: Business
# 3                  Bachelor of Arts - BA, Psychology
# 4  Master of Arts - MA, Industrial-Organizational...
#
#                                        schoolDegree2  \
# 0  Healthcare Management, Health/Health Care Admi...
# 1                                                NaN
# 2                                                NaN
# 3    Certificate, Leadership and Ethical Development
# 4                  Bachelor of Arts - BA, Psychology
#
# ...

# %%
import ethnicolr

# Predict the ethnicity using first name and last name
pred_eth = ethnicolr.pred_wiki_name(df, 'firstName', 'lastName')

pred_eth
# Out:
#      Unnamed: 0 firstName                 lastName  \
# 0             1      Sema                   Tuncer
# 1            25     Kevin  Mornot CISM, CASP, GCIH
# 2            42   Abraham                Mintesnot
# 3            59    Claire                    Selby
# 4            60    Daylon                  Frazier
# ..          ...       ...                      ...
# 154         702     Kysha              Biscoe, MBA
# 155         704    D√©j√†                  Stewart
# 156         708  Michelle                 Castillo
# 157         709       Soh                   Samuto
# 158         714     Kelly                      Sim
#
#                                           schoolDegree  \
# 0    Master of Business Administration - MS, Busine...
# 1                                                  NaN
# 2                  Major: Psychology | Minor: Business
# 3                    Bachelor of Arts - BA, Psychology
# 4    Master of Arts - MA, Industrial-Organizational...
# ...

# %%
# Print the predicted ethnicity for each person
print(pred_eth[['firstName','lastName','race']])
# Out:
#     firstName                 lastName                                  race
# 0        Sema                   Tuncer                 GreaterAfrican,Muslim
# 1       Kevin  Mornot CISM, CASP, GCIH                 GreaterAfrican,Muslim
# 2     Abraham                Mintesnot               GreaterEuropean,British
# 3      Claire                    Selby               GreaterEuropean,British
# 4      Daylon                  Frazier               GreaterEuropean,British
# ..        ...                      ...                                   ...
# 154     Kysha              Biscoe, MBA               GreaterAfrican,Africans
# 155    D√©j√†                  Stewart               GreaterEuropean,British
# 156  Michelle                 Castillo  GreaterEuropean,WestEuropean,Italian
# 157       Soh                   Samuto       Asian,GreaterEastAsian,Japanese
# 158     Kelly                      Sim               GreaterEuropean,British
#
# [159 rows x 3 columns]
