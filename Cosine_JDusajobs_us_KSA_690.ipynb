# %% [markdown]
# # Calculate Cosine Similarity Score (KSA, JD_usajobs)

# %%
import pandas as pd
import numpy as np
import re
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
JD = pd.read_csv('D:\\study\\Gmu\\Sem-4\\690\\Data\\JD_usajobs.csv')


KSA = pd.read_excel('D:\\study\\Gmu\\Sem-4\\690\\Data\\KSA.xlsx')

# %%
JD
# Out:
#                                                  Title  \
# 0                 Director (Cyber Policy and Programs)
# 1                       CYBER OPERATIONS PLANS ANALYST
# 2          SUPERVISORY CYBER POLICY-PLANS AND PROGRAMS
# 3               Information Technology (Cybersecurity)
# 4                                      PROGRAM ANALYST
# ..                                                 ...
# 478         Supervisory Biomedical Engineer (Clinical)
# 479  Diagnostic Radiologic Technologist - Intervent...
# 480        Supervisory IT Specialist (Deputy Director)
# 481             Biomedical Equipment Specialist (BESS)
# 482             Biomedical Equipment Specialist (BESS)
#
#                               Location                           Organization  \
# 0     Washington, District of Columbia  Office of the National Cyber Director
# 1                 Fort Meade, Maryland                AFELEM US CYBER COMMAND
# 2                 Fort Meade, Maryland                AFELEM US CYBER COMMAND
# 3    Anywhere in the U.S. (remote job)     Department of Energy - Agency Wide
# 4                 Fort Meade, Maryland                AFELEM US CYBER COMMAND
# ..                                 ...                                    ...
# 478                 Multiple Locations         Veterans Health Administration
# 479                 Bay Pines, Florida         Veterans Health Administration
# 480   Washington, District of Columbia   Commodity Futures Trading Commission
# 481                   Cincinnati, Ohio         Veterans Health Administration
# 482                   Cincinnati, Ohio         Veterans Health Administration
#
#                                        Department  \
# 0               Executive Office of the President
# 1                     Department of the Air Force
# 2                     Department of the Air Force
# 3                            Department of Energy
# 4                     Department of the Air Force
# ..                                            ...
# 478                Department of Veterans Affairs
# 479                Department of Veterans Affairs
# 480  Other Agencies and Independent Organizations
# 481                Department of Veterans Affairs
# 482                Department of Veterans Affairs
#
#                                   QualificationSummary
# 0    In order to qualify for the Director (Cyber Po...
# 1    In order to qualify, you must meet the special...
# 2    This is a GG-14 position in the Cyber Excepted...
# 3    You must meet the Basic Requirement and the Sp...
# 4    In order to qualify, you must meet the special...
# ..                                                 ...
# 478  Applicants pending the completion of education...
# 479  Applicants pending the completion of education...
# 480  To qualify for the CT-16, you must possess at ...
# 481  Applicants pending the completion of education...
# 482  Applicants pending the completion of education...
#
# [483 rows x 5 columns]

# %%
KSA
# Out:
#      OPM Code                   NICE Specialty Area  \
# 0         511  Cybersecurity Defense Analysis (CDA)
# 1         461                Systems Analysis (ANA)
# 2         511  Cybersecurity Defense Analysis (CDA)
# 3         531               Incident Response (CIR)
# 4         461                Systems Analysis (ANA)
# ..        ...                                   ...
# 124       511  Cybersecurity Defense Analysis (CDA)
# 125       531               Incident Response (CIR)
# 126       531               Incident Response (CIR)
# 127       461                Systems Analysis (ANA)
# 128       511  Cybersecurity Defense Analysis (CDA)
#
#                        NICE Specialty Area Description  \
# 0    Uses defensive measures and information collec...
# 1    Studies an organization's current computer sys...
# 2    Uses defensive measures and information collec...
# 3    Responds to crises or urgent situations within...
# 4    Studies an organization's current computer sys...
# ..                                                 ...
# 124  Uses defensive measures and information collec...
# 125  Responds to crises or urgent situations within...
# 126  Responds to crises or urgent situations within...
# 127  Studies an organization's current computer sys...
# 128  Uses defensive measures and information collec...
#
#                              Work Role  \
# 0                Cyber Defense Analyst
# 1             Systems Security Analyst
# 2                Cyber Defense Analyst
# 3    Cyber Defense Incident Responder
# 4             Systems Security Analyst
# ..                                 ...
# 124              Cyber Defense Analyst
# 125  Cyber Defense Incident Responder
# 126  Cyber Defense Incident Responder
# 127           Systems Security Analyst
# 128              Cyber Defense Analyst
#
#                                  Work Role Description KSA ID  \
# 0    Uses data collected from a variety of cyber de...  A0010
# 1    Responsible for the analysis and development o...  A0015
# 2    Uses data collected from a variety of cyber de...  A0066
# 3    Investigates, analyzes, and responds to cyber ...  A0121
# 4    Responsible for the analysis and development o...  A0123
# ..                                                 ...    ...
# 124  Uses data collected from a variety of cyber de...  S0169
# 125  Investigates, analyzes, and responds to cyber ...  S0173
# 126  Investigates, analyzes, and responds to cyber ...  S0365
# 127  Responsible for the analysis and development o...  S0367
# 128  Uses data collected from a variety of cyber de...  S0370
#
#                                        KSA Description
# 0                          Ability to analyze malware.
# 1    Ability to conduct vulnerability scans and rec...
# 2    Ability to accurately and completely source al...
# 3    Ability to design incident response for cloud ...
# 4    Ability to apply cybersecurity and privacy pri...
# ..                                                 ...
# 124                Skill in conducting trend analysis.
# 125   Skill in using security event correlation tools.
# 126  Skill to design incident response for cloud se...
# 127  Skill to apply cybersecurity and privacy princ...
# 128  Skill to use cyber defense Service Provider re...
#
# [129 rows x 7 columns]

# %%
def preprocess_text(text):
    # Remove punctuation and convert to lowercase
    text = re.sub(r'[^\w\s]', '', str(text).lower())
    # Remove stop words
    stop_words = set(stopwords.words('english'))
    text = ' '.join([word for word in text.split() if word not in stop_words])
    # Stem the words
    stemmer = PorterStemmer()
    text = ' '.join([stemmer.stem(word) for word in text.split()])
    # Lemmatize the words
    lemmatizer = WordNetLemmatizer()
    text = ' '.join([lemmatizer.lemmatize(word) for word in text.split()])
    return text



JD['QualificationSummary'] = JD['QualificationSummary'].apply(preprocess_text)
KSA['KSA Description'] = KSA['KSA Description'].apply(preprocess_text)

# %%
JD['QualificationSummary']
# Out:
# 0      order qualifi director cyber polici program po...
# 1      order qualifi must meet special experi requir ...
# 2      gg14 posit cyber except servic ce gg14 duti pr...
# 3      must meet basic requir special experi qualifi ...
# 4      order qualifi must meet special experi requir ...
#                              ...
# 478    applic pend complet educ certificationlicensur...
# 479    applic pend complet educ certificationlicensur...
# 480    qualifi ct16 must posse least one year special...
# 481    applic pend complet educ certificationlicensur...
# 482    applic pend complet educ certificationlicensur...
# Name: QualificationSummary, Length: 483, dtype: object

# %%
KSA['KSA Description']
# Out:
# 0                                     abil analyz malwar
# 1      abil conduct vulner scan recogn vulner secur s...
# 2      abil accur complet sourc data use intellig ass...
# 3           abil design incid respons cloud servic model
# 4      abil appli cybersecur privaci principl organiz...
#                              ...
# 124                          skill conduct trend analysi
# 125                    skill use secur event correl tool
# 126        skill design incid respons cloud servic model
# 127    skill appli cybersecur privaci principl organi...
# 128    skill use cyber defens servic provid report st...
# Name: KSA Description, Length: 129, dtype: object

# %%
KSA_string = ' '.join(KSA['KSA Description'])


KSA_df = pd.DataFrame({'KSA': KSA_string}, index=[0])


KSA_df
# Out:
#                                                  KSA
# 0  abil analyz malwar abil conduct vulner scan re...

# %%
concatenated_text = pd.concat([JD['QualificationSummary'], KSA_df['KSA']], ignore_index=True)


concatenated_text
# Out:
# 0      order qualifi director cyber polici program po...
# 1      order qualifi must meet special experi requir ...
# 2      gg14 posit cyber except servic ce gg14 duti pr...
# 3      must meet basic requir special experi qualifi ...
# 4      order qualifi must meet special experi requir ...
#                              ...
# 479    applic pend complet educ certificationlicensur...
# 480    qualifi ct16 must posse least one year special...
# 481    applic pend complet educ certificationlicensur...
# 482    applic pend complet educ certificationlicensur...
# 483    abil analyz malwar abil conduct vulner scan re...
# Length: 484, dtype: object

# %% [markdown]
# ## Approach 1. use CountVectorizer

# %%
ctvectorizer = CountVectorizer()


ct_matrix = ctvectorizer.fit_transform(concatenated_text)


ct_matrix
# Out:
# <484x4324 sparse matrix of type '<class 'numpy.int64'>'
# 	with 89976 stored elements in Compressed Sparse Row format>

# %%
cosine_ct = cosine_similarity(ct_matrix[:-1], ct_matrix[-1])



JD['cos_KSA_countvect'] = cosine_ct[:,0]

# %%
JD['cos_KSA_countvect']=JD['cos_KSA_countvect']*100

# %%
print(JD['cos_KSA_countvect'].describe())
# Out:
# count    483.000000
# mean      19.458825
# std        9.382529
# min        0.000000
# 25%       13.562579
# 50%       17.651284
# 75%       24.710630
# max       51.419322
# Name: cos_KSA_countvect, dtype: float64

# %% [markdown]
# ## Approach 2. use TF-IDF vectorizer

# %%
tfvectorizer = TfidfVectorizer()


tfidf_matrix = tfvectorizer.fit_transform(concatenated_text)


cosine_tfidf = cosine_similarity(tfidf_matrix[:-1], tfidf_matrix[-1])



JD['cos_KSA_tfidf'] = cosine_tfidf[:,0]

# %%
JD['cos_KSA_tfidf']=JD['cos_KSA_tfidf']*100

# %%
print(JD['cos_KSA_tfidf'].describe())
# Out:
# count    483.000000
# mean      12.463967
# std        6.228819
# min        0.000000
# 25%        8.250293
# 50%       11.269752
# 75%       16.426129
# max       36.063722
# Name: cos_KSA_tfidf, dtype: float64

# %%
JD
# Out:
#                                                  Title  \
# 0                 Director (Cyber Policy and Programs)
# 1                       CYBER OPERATIONS PLANS ANALYST
# 2          SUPERVISORY CYBER POLICY-PLANS AND PROGRAMS
# 3               Information Technology (Cybersecurity)
# 4                                      PROGRAM ANALYST
# ..                                                 ...
# 478         Supervisory Biomedical Engineer (Clinical)
# 479  Diagnostic Radiologic Technologist - Intervent...
# 480        Supervisory IT Specialist (Deputy Director)
# 481             Biomedical Equipment Specialist (BESS)
# 482             Biomedical Equipment Specialist (BESS)
#
#                               Location                           Organization  \
# 0     Washington, District of Columbia  Office of the National Cyber Director
# 1                 Fort Meade, Maryland                AFELEM US CYBER COMMAND
# 2                 Fort Meade, Maryland                AFELEM US CYBER COMMAND
# 3    Anywhere in the U.S. (remote job)     Department of Energy - Agency Wide
# 4                 Fort Meade, Maryland                AFELEM US CYBER COMMAND
# ..                                 ...                                    ...
# 478                 Multiple Locations         Veterans Health Administration
# 479                 Bay Pines, Florida         Veterans Health Administration
# 480   Washington, District of Columbia   Commodity Futures Trading Commission
# 481                   Cincinnati, Ohio         Veterans Health Administration
# 482                   Cincinnati, Ohio         Veterans Health Administration
#
#                                        Department  \
# 0               Executive Office of the President
# 1                     Department of the Air Force
# 2                     Department of the Air Force
# 3                            Department of Energy
# 4                     Department of the Air Force
# ..                                            ...
# 478                Department of Veterans Affairs
# 479                Department of Veterans Affairs
# 480  Other Agencies and Independent Organizations
# 481                Department of Veterans Affairs
# 482                Department of Veterans Affairs
#
#                                   QualificationSummary  cos_KSA_countvect  \
# 0    order qualifi director cyber polici program po...          16.865809
# 1    order qualifi must meet special experi requir ...          29.378216
# 2    gg14 posit cyber except servic ce gg14 duti pr...          32.714291
# 3    must meet basic requir special experi qualifi ...          21.614236
# 4    order qualifi must meet special experi requir ...          43.152110
# ..                                                 ...                ...
# 478  applic pend complet educ certificationlicensur...          13.836965
# 479  applic pend complet educ certificationlicensur...          24.031446
# 480  qualifi ct16 must posse least one year special...          27.591750
# 481  applic pend complet educ certificationlicensur...          17.427543
# 482  applic pend complet educ certificationlicensur...          17.427543
#
#      cos_KSA_tfidf
# 0        15.881155
# 1        16.372615
# 2        18.452627
# 3        18.228973
# 4        22.450201
# ..             ...
# 478       8.101932
# 479      10.096924
# 480      17.679071
# 481      10.313489
# 482      10.313489
#
# [483 rows x 7 columns]

# %%
JD[(JD['cos_KSA_countvect'] > 10) ]
# Out:
#                                                  Title  \
# 0                 Director (Cyber Policy and Programs)
# 1                       CYBER OPERATIONS PLANS ANALYST
# 2          SUPERVISORY CYBER POLICY-PLANS AND PROGRAMS
# 3               Information Technology (Cybersecurity)
# 4                                      PROGRAM ANALYST
# ..                                                 ...
# 478         Supervisory Biomedical Engineer (Clinical)
# 479  Diagnostic Radiologic Technologist - Intervent...
# 480        Supervisory IT Specialist (Deputy Director)
# 481             Biomedical Equipment Specialist (BESS)
# 482             Biomedical Equipment Specialist (BESS)
#
#                               Location                           Organization  \
# 0     Washington, District of Columbia  Office of the National Cyber Director
# 1                 Fort Meade, Maryland                AFELEM US CYBER COMMAND
# 2                 Fort Meade, Maryland                AFELEM US CYBER COMMAND
# 3    Anywhere in the U.S. (remote job)     Department of Energy - Agency Wide
# 4                 Fort Meade, Maryland                AFELEM US CYBER COMMAND
# ..                                 ...                                    ...
# 478                 Multiple Locations         Veterans Health Administration
# 479                 Bay Pines, Florida         Veterans Health Administration
# 480   Washington, District of Columbia   Commodity Futures Trading Commission
# 481                   Cincinnati, Ohio         Veterans Health Administration
# 482                   Cincinnati, Ohio         Veterans Health Administration
#
#                                        Department  \
# 0               Executive Office of the President
# 1                     Department of the Air Force
# 2                     Department of the Air Force
# 3                            Department of Energy
# 4                     Department of the Air Force
# ..                                            ...
# 478                Department of Veterans Affairs
# 479                Department of Veterans Affairs
# 480  Other Agencies and Independent Organizations
# 481                Department of Veterans Affairs
# 482                Department of Veterans Affairs
#
#                                   QualificationSummary  cos_KSA_countvect  \
# 0    order qualifi director cyber polici program po...          16.865809
# 1    order qualifi must meet special experi requir ...          29.378216
# 2    gg14 posit cyber except servic ce gg14 duti pr...          32.714291
# 3    must meet basic requir special experi qualifi ...          21.614236
# 4    order qualifi must meet special experi requir ...          43.152110
# ..                                                 ...                ...
# 478  applic pend complet educ certificationlicensur...          13.836965
# 479  applic pend complet educ certificationlicensur...          24.031446
# 480  qualifi ct16 must posse least one year special...          27.591750
# 481  applic pend complet educ certificationlicensur...          17.427543
# 482  applic pend complet educ certificationlicensur...          17.427543
#
#      cos_KSA_tfidf
# 0        15.881155
# 1        16.372615
# 2        18.452627
# 3        18.228973
# 4        22.450201
# ..             ...
# 478       8.101932
# 479      10.096924
# 480      17.679071
# 481      10.313489
# 482      10.313489
#
# [423 rows x 7 columns]

# %%
J1 = JD['Location'].str.split(",", expand = True)

# %%
J1.columns=["place","State","Nan"]

# %%
JD=pd.concat([JD,J1],axis=1)

# %%
JD=JD.drop(columns=['Location','Nan'])

# %%
JD.to_csv("D:\\study\\Gmu\\Sem-4\\690\\Data\\JD.csv")
