# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import time
import pandas as pd

# %%
job_name = "Cyber"
country_name = "United States"

job_url ="";
for item in job_name.split(" "):
    if item != job_name.split(" ")[-1]:
        job_url = job_url + item + "%20"
    else:
        job_url = job_url + item

country_url ="";
for item in country_name.split(" "):
    if item != country_name.split(" ")[-1]:
        country_url = country_url + item + "%20"
    else:
        country_url = country_url + item

url = "https://www.linkedin.com/jobs/search?keywords={0}&location={1}&geoId=103644278&trk=public_jobs_jobs-search-bar_search-submit&position=1&pageNum=0"
url=url.format(job_url,country_url)

# %%
url
# Out:
# 'https://www.linkedin.com/jobs/search?keywords=Cyber&location=United%20States&geoId=103644278&trk=public_jobs_jobs-search-bar_search-submit&position=1&pageNum=0'

# %%
# Creating a webdriver instance
driver = webdriver.Chrome("ChromeDriver_Path/chromedriver")
# Opening the url we have just defined in our browser
driver.get(url)
# Out:
# <ipython-input-4-cdb95a8fc94a>:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome("ChromeDriver_Path/chromedriver")

# %%
#We find how many jobs are offered.
jobs_num = driver.find_element(By.CSS_SELECTOR,"h1>span").get_attribute("innerText")
if len(jobs_num.split(',')) > 1:
    jobs_num = int(jobs_num.split(',')[0])*1000
else:
    jobs_num = int(jobs_num)

jobs_num   = int(jobs_num)

#We create a while loop to browse all jobs. 
i = 2
while i <= int(jobs_num/2)+1:
    #We keep scrollind down to the end of the view.
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    i = i + 1
    print("Current at: ", i, "Percentage at: ", ((i+1)/(int(jobs_num/2)+1))*100, "%",end="\r")
    try:
        #We try to click on the load more results buttons in case it is already displayed.
        infinite_scroller_button = driver.find_element(By.XPATH, ".//button[@aria-label='Load more results']")
        infinite_scroller_button.click()
        time.sleep(0.1)
    except:
        #If there is no button, there will be an error, so we keep scrolling down.
        time.sleep(0.1)
        pass
# Out:
# Current at:  26002 Percentage at:  100.00769201184569 %

# %%
#We get a list containing all jobs that we have found.
job_lists = driver.find_element(By.CLASS_NAME,"jobs-search__results-list")
jobs = job_lists.find_elements(By.TAG_NAME,"li") # return a list

#We declare void list to keep track of all obtaind data.
job_title_list = []
company_name_list = []
location_list = []
date_list = []
job_link_list = []

#We loof over every job and obtain all the wanted info.
for job in jobs:
    #job_title
    job_title = job.find_element(By.CSS_SELECTOR,"h3").get_attribute("innerText")
    job_title_list.append(job_title)
    
    #company_name
    company_name = job.find_element(By.CSS_SELECTOR,"h4").get_attribute("innerText")
    company_name_list.append(company_name)
    
    #location
    location = job.find_element(By.CSS_SELECTOR,"div>div>span").get_attribute("innerText")
    location_list.append(location)
    
    #date
    date = job.find_element(By.CSS_SELECTOR,"div>div>time").get_attribute("datetime")
    date_list.append(date)
    
    #job_link
    job_link = job.find_element(By.CSS_SELECTOR,"a").get_attribute("href")
    job_link_list.append(job_link)

# %%
jd = [] #job_description
seniority = []
emp_type = []
job_func = []
job_ind = []
for item in range(len(jobs)):
    print(item)
    job_func0=[]
    industries0=[]
    # clicking job to view job details
    
    #__________________________________________________________________________ JOB Link
    
    try: 
        job_click_path = f'/html/body/div/div/main/section/ul/li[{item+1}]'
        job_click = job.find_element(By.XPATH,job_click_path).click()
    except:
        pass
    #job_click = job.find_element(By.XPATH,'.//a[@class="base-card_full-link"]')
    
    #__________________________________________________________________________ JOB Description
    jd_path = '/html/body/div/div/section/div/div/section/div/div/section/div'
    try:
        jd0 = job.find_element(By.XPATH,jd_path).get_attribute('innerText')
        jd.append(jd0)
    except:
        jd.append(None)
        pass
    
    #__________________________________________________________________________ JOB Seniority
    seniority_path='/html/body/div/div/section/div/div/section/div/ul/li[1]/span'
    
    try:
        seniority0 = job.find_element(By.XPATH,seniority_path).get_attribute('innerText')
        seniority.append(seniority0)
    except:
        seniority.append(None)
        pass

    #__________________________________________________________________________ JOB Time
    emp_type_path='/html/body/div/div/section/div/div/section/div/ul/li[2]/span'
    
    try:
        emp_type0 = job.find_element(By.XPATH,emp_type_path).get_attribute('innerText')
        emp_type.append(emp_type0)
    except:
        emp_type.append(None)
        pass
    
    #__________________________________________________________________________ JOB Function
    function_path='/html/body/div/div/section/div/div/section/div/ul/li[3]/span'
    
    try:
        func0 = job.find_element(By.XPATH,function_path).get_attribute('innerText')
        job_func.append(func0)
    except:
        job_func.append(None)
        pass

    #__________________________________________________________________________ JOB Industry
    industry_path='/html/body/div/div/section/div/div/section/div/ul/li[4]/span'
    
    try:
        ind0 = job.find_element(By.XPATH,industry_path).get_attribute('innerText')
        job_ind.append(ind0)
    except:
        job_ind.append(None)
        pass
    
    print("Current at: ", item, "Percentage at: ", (item+1)/len(jobs)*100, "%")
# Out:
# 0
# Current at:  0 Percentage at:  4.0 %
# 1
# Current at:  1 Percentage at:  8.0 %
# 2
# Current at:  2 Percentage at:  12.0 %
# 3
# Current at:  3 Percentage at:  16.0 %
# 4
# Current at:  4 Percentage at:  20.0 %
# 5
# Current at:  5 Percentage at:  24.0 %
# 6
# Current at:  6 Percentage at:  28.000000000000004 %
# 7
# Current at:  7 Percentage at:  32.0 %
# 8
# Current at:  8 Percentage at:  36.0 %
# 9
# Current at:  9 Percentage at:  40.0 %
# 10
# Current at:  10 Percentage at:  44.0 %
# 11
# Current at:  11 Percentage at:  48.0 %
# 12
# Current at:  12 Percentage at:  52.0 %
# 13
# Current at:  13 Percentage at:  56.00000000000001 %
# 14
# Current at:  14 Percentage at:  60.0 %
# 15
# Current at:  15 Percentage at:  64.0 %
# 16
# Current at:  16 Percentage at:  68.0 %
# 17
# Current at:  17 Percentage at:  72.0 %
# 18
# Current at:  18 Percentage at:  76.0 %
# 19
# Current at:  19 Percentage at:  80.0 %
# 20
# Current at:  20 Percentage at:  84.0 %
# 21
# Current at:  21 Percentage at:  88.0 %
# 22
# Current at:  22 Percentage at:  92.0 %
# 23
# Current at:  23 Percentage at:  96.0 %
# 24
# Current at:  24 Percentage at:  100.0 %

# %%
job_data = pd.DataFrame({
    'Date': date_list,
    'Company': company_name_list,
    'Title': job_title_list,
    'Location': location_list,
    'Description': jd,
    'Level': seniority,
    'Type': emp_type,
    'Function': job_func,
    'Industry': job_ind,
    'Link': job_link_list
})

# %%
# cleaning columns
job_data['Description'] = job_data['Description'].str.replace('\n',' ')
job_data["Type"]=job_data["Type"].str.replace('\n',' ')
job_data["Function"]=job_data["Function"].str.replace('\n',' ')
job_data["Level"]=job_data["Level"].str.replace('\n',' ')
job_data["Industry"]=job_data["Industry"].str.replace('\n',' ')

# %%
job_data
# Out:
#           Date                         Company  \
# 0   2023-04-03                       White Cap
# 1   2023-04-03                   Stelvio Group
# 2   2023-04-03  Social Security Administration
# 3   2023-04-03  Social Security Administration
# 4   2023-04-03  Social Security Administration
# 5   2023-04-03  Social Security Administration
# 6   2023-04-03  Social Security Administration
# 7   2023-04-03  Social Security Administration
# 8   2023-04-03  Social Security Administration
# 9   2023-04-03  Social Security Administration
# 10  2023-04-03  Social Security Administration
# 11  2023-03-18          Peridot Solutions, LLC
# 12  2023-03-31                       Dataprise
# 13  2023-03-12                 CO Technologies
# 14  2023-04-03                          Google
# 15  2023-02-10                          Aperia
# 16  2023-03-15              Watershed Security
# 17  2023-03-31                       Dataprise
# 18  2023-03-11                     SoLa Impact
# 19  2023-03-17              Watershed Security
# 20  2023-04-03                         My3Tech
# 21  2023-03-08                  Surge Staffing
# 22  2023-02-27                          AERMOR
# 23  2023-03-14                 Lockheed Martin
# 24  2023-03-18                 VForce Infotech
#
#                                                 Title                Location  \
# 0                        Information Security Analyst           United States
# 1                        Information Security Analyst  Florida, United States
# 2         IT Specialist/IT Cyber Specialist (INFOSEC)            New York, NY
# 3         IT Specialist/IT Cyber Specialist (INFOSEC)             Atlanta, GA
# 4         IT Specialist/IT Cyber Specialist (INFOSEC)        Philadelphia, PA
# 5         IT Specialist/IT Cyber Specialist (INFOSEC)         Kansas City, MO
# 6         IT Specialist/IT Cyber Specialist (INFOSEC)       Durham County, NC
# 7         IT Specialist/IT Cyber Specialist (INFOSEC)             Chicago, IL
# 8         IT Specialist/IT Cyber Specialist (INFOSEC)             Seattle, WA
# 9         IT Specialist/IT Cyber Specialist (INFOSEC)       San Francisco, CA
# 10        IT Specialist/IT Cyber Specialist (INFOSEC)              Dallas, TX
# 11                               Cyber Threat Analyst          Washington, DC
# 12                           Cyber Security Analyst I           United States
# 13                              Cybersecurity Analyst      Virginia Beach, VA
# 14                               Cyber Threat Analyst            New York, NY
# 15  Cybersecurity (Cyber Intelligence Operations- ...              Dallas, TX
# 16                              Cyber Support Analyst             Norfolk, VA
# 17                          Cyber Security Analyst II           United States
# 18                       IT/Cyber Security Technician         Los Angeles, CA
# 19                              Cyber Support Analyst             Norfolk, VA
# 20                              Cyber Defence Analyst           United States
# 21                             Cyber Security Analyst            Columbus, OH
# 22                                  Jr. Cyber Analyst         Albuquerque, NM
# 23                              Cyber Security Intern            Bethesda, MD
# 24                             Cyber Security Analyst              Edison, NJ
#
#    Description Level  Type Function Industry  \
# 0         None  None  None     None     None
# 1         None  None  None     None     None
# 2         None  None  None     None     None
# 3         None  None  None     None     None
# 4         None  None  None     None     None
# 5         None  None  None     None     None
# 6         None  None  None     None     None
# 7         None  None  None     None     None
# 8         None  None  None     None     None
# 9         None  None  None     None     None
# 10        None  None  None     None     None
# 11        None  None  None     None     None
# 12        None  None  None     None     None
# 13        None  None  None     None     None
# 14        None  None  None     None     None
# 15        None  None  None     None     None
# 16        None  None  None     None     None
# 17        None  None  None     None     None
# 18        None  None  None     None     None
# 19        None  None  None     None     None
# 20        None  None  None     None     None
# 21        None  None  None     None     None
# 22        None  None  None     None     None
# 23        None  None  None     None     None
# 24        None  None  None     None     None
#
#                                                  Link
# 0   https://www.linkedin.com/jobs/view/information...
# 1   https://www.linkedin.com/jobs/view/information...
# 2   https://www.linkedin.com/jobs/view/it-speciali...
# 3   https://www.linkedin.com/jobs/view/it-speciali...
# 4   https://www.linkedin.com/jobs/view/it-speciali...
# 5   https://www.linkedin.com/jobs/view/it-speciali...
# 6   https://www.linkedin.com/jobs/view/it-speciali...
# 7   https://www.linkedin.com/jobs/view/it-speciali...
# 8   https://www.linkedin.com/jobs/view/it-speciali...
# 9   https://www.linkedin.com/jobs/view/it-speciali...
# 10  https://www.linkedin.com/jobs/view/it-speciali...
# 11  https://www.linkedin.com/jobs/view/cyber-threa...
# 12  https://www.linkedin.com/jobs/view/cyber-secur...
# 13  https://www.linkedin.com/jobs/view/cybersecuri...
# 14  https://www.linkedin.com/jobs/view/cyber-threa...
# 15  https://www.linkedin.com/jobs/view/cybersecuri...
# 16  https://www.linkedin.com/jobs/view/cyber-suppo...
# 17  https://www.linkedin.com/jobs/view/cyber-secur...
# 18  https://www.linkedin.com/jobs/view/it-cyber-se...
# 19  https://www.linkedin.com/jobs/view/cyber-suppo...
# 20  https://www.linkedin.com/jobs/view/cyber-defen...
# 21  https://www.linkedin.com/jobs/view/cyber-secur...
# 22  https://www.linkedin.com/jobs/view/jr-cyber-an...
# 23  https://www.linkedin.com/jobs/view/cyber-secur...
# 24  https://www.linkedin.com/jobs/view/cyber-secur...

# %%
job_data.to_csv('D:\\study\\Gmu\\Sem-4\\690\\Data\\JD\\Job_Des.csv', index = False)
